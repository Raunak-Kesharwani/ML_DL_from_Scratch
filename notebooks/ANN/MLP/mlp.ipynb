# %%
import numpy as np 
import pandas as pd

# %%
def sigmoid(z):
    return 1/(1+ np.exp(-z))
def BCE(y , y_pred):
    return -[y*np.log(y_pred) + (1-y)*(np.log(1-y_pred))]

# %%
def mlp(X , y , lr= 0.01 , epochs = 20 ):
    # 3 layer MLP input layer , hidden layer , output layer 
    h1_nodes = 2
    out_layer1 = np.zeros(2)
    # for first layer 
    # using the technique named as glorat 
    layer_1weights = np.random.randn(h1_nodes , 1 + X.shape[1]) / (1/X.shape[1])**(1/2)
    
    # for second layer
    o1_nodes = 1
    out_layer2 = np.zeros(1)
    layer_2weights = np.random.randn(o1_nodes , X.shape[1]) / (1/X.shape[1])**(1/2)

    # now it's time to input
    for _ in range(epochs):
        for i in range(X.shape[0]):
            r = np.random.randint(0 , X.shape[0]):
            out_layer1[0] = X[r] @ layer_1weights[0][1:] + layer_1weights[0][0]
            out_layer1[1] = X[r] @ layer_1weights[1][1:] + layer_1weights[1][0]
            out_layer2[0] = out_layer1 @ layer_2weights[1:] + layer_2weights[0]
            y_pred = sigmoid(out_layer2[0])
            L = BCE(y[r], y_pred)
            layer_2weights -= lr*layer_2new
            layer_1weights -= lr*layer

# %%
h_nodes = 2
# for first layer 
first_W = np.random.rand(h_nodes , 2+1)

first_W
# Out:
# array([[0.43138043, 0.18930072, 0.53156702],
#        [0.39824502, 1.        , 0.11742117]])

# %%
first_W

# %%
np.random.random((2,3))
# Out:
# array([[0.53069452, 0.07451145, 0.15496249],
#        [0.93742025, 0.46497835, 0.14513092]])
